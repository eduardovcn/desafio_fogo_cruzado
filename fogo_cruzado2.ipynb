# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:/Users/Acer/Desktop/fogo_cruzado2/exercicio2.xlsx")

# %% [markdown]
# BUSCANDO DADOS NULOS, BASEADO NO DICIONÁRIO DO DESAFIO.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1366 entries, 0 to 1365
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ocorrencia               1366 non-null   int64
#  1   status                      1366 non-null   object
#  2   uf                          1366 non-null   object
#  3   cidade                      1366 non-null   object
#  4   endereco                    1366 non-null   object
#  5   bairro                      1363 non-null   object
#  6   sub_bairro                  103 non-null    object
#  7   localidade                  423 non-null    object
#  8   latitude                    1366 non-null   float64
#  9   longitude                   1366 non-null   float64
#  10  data_ocorrencia             1366 non-null   datetime64[ns]
#  11  presenca_agentes            1366 non-null   object
#  12  acao_policial               1366 non-null   object
# ...

# %% [markdown]
# EXERCICIO 2: Fazer a limpeza dos dados

# %%
bairros_nulos = df.loc[df['bairro'].isnull()]
bairros_nulos
# Out:
#       id_ocorrencia    status     uf                 cidade  \
# 212           67951  Approved   Pará  SANTA BARBARA DO PARA
# 259           67902  Approved  Bahia           DIAS D'AVILA
# 1107          66994  Approved   Pará                  BELEM
#
#                                                endereco bairro sub_bairro  \
# 212       Santa Bárbara do Pará - PA, 68798-000, Brasil    NaN        NaN
# 259   R. dos Rodoviários - Lama Preta, Dias d'Ávila ...    NaN        NaN
# 1107  Vila da Bacabeira - Mosqueiro, Belém - PA, Brasil    NaN        NaN
#
#      localidade   latitude  longitude  ... civis_feridos_ocorrencia  \
# 212         NaN  -1.226285 -48.297992  ...                      NaN
# 259         NaN -12.603673 -38.316366  ...                      1.0
# 1107        NaN  -1.145473 -48.325990  ...                      NaN
#
#      agentes_mortos_ocorrencia agentes_feridos_ocorrencia  chacina_ocorrencia  \
# ...

# %%
valores_nulos = df.isnull().sum()

# %%
valores_nulos
# Out:
# id_ocorrencia                    0
# status                           0
# uf                               0
# cidade                           0
# endereco                         0
# bairro                           3
# sub_bairro                    1263
# localidade                     943
# latitude                         0
# longitude                        0
# data_ocorrencia                  0
# presenca_agentes                 0
# acao_policial                    0
# civis_mortos_ocorrencia        616
# civis_feridos_ocorrencia      1094
# agentes_mortos_ocorrencia     1347
# agentes_feridos_ocorrencia    1345
# chacina_ocorrencia               0
# unidades_policiais             921
# motivo_principal                 0
# motivos_complementares         748
# outros_recortes               1240
# transporte_interrompido          0
# ocorrencia_relacionada        1354
# dtype: int64

# %% [markdown]
# CHECANDO SE HÁ ALGUMA IRREGULARIDADE NA VARIÁVEL DATA

# %%
df_data = df["data_ocorrencia"]
df_data
# Out:
# 0      2024-11-17 10:00:00
# 1      2024-11-18 23:33:00
# 2      2024-11-18 20:00:00
# 3      2024-11-18 08:00:00
# 4      2024-11-18 19:00:00
#                ...
# 1361   2024-09-01 16:30:00
# 1362   2024-09-02 11:30:00
# 1363   2024-09-02 00:20:00
# 1364   2024-09-01 00:00:00
# 1365   2024-09-01 22:00:00
# Name: data_ocorrencia, Length: 1366, dtype: datetime64[ns]

# %% [markdown]
# AQUI PERCEBEMOS QUE A VARIÁVEL EM QUESTÃO NÃO POSSUI UM PADRÃO NOS DADOS.

# %%
df.loc[df["ocorrencia_relacionada"].notnull()]
# Out:
#       id_ocorrencia    status          uf                   cidade  \
# 36            68140  Approved        Pará                    BELEM
# 68            68107  Approved        Pará               ANANINDEUA
# 115           68055  Approved        Pará                    BELEM
# 185           67980  Approved        Pará                    BELEM
# 190           67975  Approved        Pará                    BELEM
# 261           67900  Approved       Bahia         MATA DE SAO JOAO
# 538           67600  Approved        Pará                    BELEM
# 590           67544  Approved        Pará                CASTANHAL
# 594           67540  Approved  Pernambuco  CABO DE SANTO AGOSTINHO
# 623           67508  Approved  Pernambuco                   RECIFE
# 949           67160  Approved  Pernambuco                   RECIFE
# 1356          66732  Approved       Bahia                 SALVADOR
#
#                                                endereco               bairro  \
# ...
