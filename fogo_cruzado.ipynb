# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns   
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame(pd.read_excel("C:/Users/Acer/Desktop/fogo_cruzado2/exercicio1.xlsx"))

# %%
df_ocorrencia = df[df["ocorrencia_relacionada"].notnull()]
df_ocorrencia
# Out:
#       id_ocorrencia              uf                   cidade  \
# 54            68913           Bahia         LAURO DE FREITAS
# 74            68882            Pará                    BELEM
# 123           68827      Pernambuco  CABO DE SANTO AGOSTINHO
# 272           68665      Pernambuco                   OLINDA
# 318           68616           Bahia                 SALVADOR
# ...             ...             ...                      ...
# 6524          61938            Pará                BENEVIDES
# 6550          61910            Pará                    BELEM
# 6629          61826            Pará               ANANINDEUA
# 6669          61785  Rio de Janeiro           RIO DE JANEIRO
# 6670          61784  Rio de Janeiro           RIO DE JANEIRO
#
#                                                endereco               bairro  \
# 54    Rua Lagoa dos Patos - Lagoa dos Patos - Ipitan...             IPITANGA
# ...

# %%
#visualizar todas as variáveis presentes no dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769 entries, 0 to 6768
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ocorrencia               6769 non-null   int64
#  1   uf                          6769 non-null   object
#  2   cidade                      6769 non-null   object
#  3   endereco                    6769 non-null   object
#  4   bairro                      6769 non-null   object
#  5   sub_bairro                  483 non-null    object
#  6   localidade                  2637 non-null   object
#  7   latitude                    6769 non-null   float64
#  8   longitude                   6769 non-null   float64
#  9   data_ocorrencia             6769 non-null   datetime64[ns]
#  10  data de cadastro            6769 non-null   datetime64[ns]
#  11  última atualização          6769 non-null   datetime64[ns]
# ...

# %% [markdown]
# Respondendo a pergunta 1.

# %%
df["motivo_principal"].value_counts()
# Out:
# motivo_principal
# Homicidio/Tentativa          2806
# Ação policial                1357
# Não identificado             1082
# Tentativa/Roubo               521
# Disputa                       371
# Operação policial             346
# Briga                         110
# Tiros a esmo                   41
# Ataque a civis                 38
# Tentativa/Roubo de cargas      19
# Sequestro/Cárcere Privado      16
# Arrastão                       16
# Disparo Acidental              13
# Suicídio                       11
# Outro                          10
# Tortura                        10
# Rebelião/Fuga de presos         1
# Tentativa/Roubo a banco         1
# Name: count, dtype: int64

# %% [markdown]
# Para responder a segunda parte da pergunta 1, irei filtrar o dataframe para visualizar apenas as linhas onde 'motivo_principal' é 'Tiros a esmo'

# %%
df_tiro_a_esmo = df[df['motivo_principal'] == 'Tiros a esmo']

# Exibindo o dataframe filtrado
df_tiro_a_esmo
# Out:
#       id_ocorrencia              uf                   cidade  \
# 94            68857  Rio de Janeiro           RIO DE JANEIRO
# 266           68671      Pernambuco                   OLINDA
# 267           68670            Pará                    BELEM
# 279           68658  Rio de Janeiro           RIO DE JANEIRO
# 377           68551            Pará                    BELEM
# 391           68536           Bahia                 SALVADOR
# 425           68501      Pernambuco                   RECIFE
# 581           68336      Pernambuco               CAMARAGIBE
# 582           68335      Pernambuco               CAMARAGIBE
# 615           68302      Pernambuco                   RECIFE
# 866           68041  Rio de Janeiro           RIO DE JANEIRO
# 974           67924            Pará                    BELEM
# 998           67898  Rio de Janeiro           RIO DE JANEIRO
# 1287          67586           Bahia                 SALVADOR
# ...

# %%
df_acao_policial = df_tiro_a_esmo["acao_policial"]
df_acao_policial
# Out:
# 94      Não
# 266     Não
# 267     Não
# 279     Não
# 377     Não
# 391     Não
# 425     Não
# 581     Não
# 582     Não
# 615     Não
# 866     Não
# 974     Não
# 998     Não
# 1287    Não
# 1431    Não
# 1511    Não
# 1586    Não
# 1589    Não
# 1616    Não
# 1751    Sim
# 1906    Não
# 2022    Não
# 2401    Não
# 2753    Não
# 3074    Não
# 3145    Não
# 3539    Não
# 3850    Não
# 4110    Não
# 4218    Não
# 4482    Não
# 4487    Não
# 4608    Não
# 4652    Não
# 4725    Não
# 5021    Não
# 5534    Não
# 5856    Não
# 6452    Não
# 6490    Não
# 6711    Não
# Name: acao_policial, dtype: object

# %% [markdown]
# Transformando a variável categórica em numérica para calcular a porcentagem.

# %%
le = LabelEncoder()
df_acao_policial = le.fit_transform(df_acao_policial)

# %%
df_acao_policial.mean()*100
# Out:
# np.float64(2.4390243902439024)

# %% [markdown]
# Respondendo a pergunta 4.

# %%
mais_tiroteio = df_tiro_a_esmo.sort_values("uf")
mais_tiroteio["bairro"].value_counts()
# Out:
# bairro
# MARE                    4
# LIBERDADE               2
# OLAVO BILAC             2
# PARQUE VERDE            2
# MUSSURUNGA              1
# SUSSUARANA              1
# PARIPE                  1
# JARDIM SANTO INACIO     1
# BEIRU/TANCREDO NEVES    1
# VILA CANARIA            1
# PERNAMBUES              1
# LOBATO                  1
# PEDREIRA                1
# CAMPINA                 1
# CARANAMDUBA             1
# TERRA FIRME             1
# VARADOURO               1
# IPITANGA                1
# CAPELINHA               1
# IPUTINGA                1
# JOAO PAULO II           1
# TEJUCOPAPO              1
# VIANA                   1
# RAMOS                   1
# INHAUMA                 1
# ILHA JOANA BEZERRA      1
# CAJUEIRO SECO           1
# BRAS DE PINA            1
# CAMPINHO                1
# MADUREIRA               1
# PACIENCIA               1
# JARDIM CARIOCA          1
# BANCO DE AREIA          1
# HELIOPOLIS              1
# JACAREZINHO             1
# ...

# %% [markdown]
# Pergunta 2: Quantas chacinas foram registradas em 2024? E qual estado registrou menos vítimas desse fenômeno?
#
#
# Foram registrados 85 casos de chacina no ano de 2024. Sendo o estado de Pernambuco o que registrou menos casos (5 casos. Aproximadamente 5,88%)

# %%
chacina =df[df["chacina_ocorrencia"] == "Sim"]
chacina
# Out:
#       id_ocorrencia              uf                   cidade  \
# 54            68913           Bahia         LAURO DE FREITAS
# 55            68912           Bahia         LAURO DE FREITAS
# 185           68754           Bahia                 CAMACARI
# 294           68643  Rio de Janeiro              NOVA IGUAÇU
# 349           68584      Pernambuco  CABO DE SANTO AGOSTINHO
# ...             ...             ...                      ...
# 6550          61910            Pará                    BELEM
# 6624          61831  Rio de Janeiro                  NITERÓI
# 6629          61826            Pará               ANANINDEUA
# 6669          61785  Rio de Janeiro           RIO DE JANEIRO
# 6727          61724  Rio de Janeiro                  NITERÓI
#
#                                                endereco         bairro  \
# 54    Rua Lagoa dos Patos - Lagoa dos Patos - Ipitan...       IPITANGA
# 55       Chafariz, Vila Praiana - Lauro de Freitas - BA   VILA PRAIANA
# ...

# %%
chacina["uf"].value_counts()
# Out:
# uf
# Rio de Janeiro    47
# Bahia             27
# Pará               6
# Pernambuco         5
# Name: count, dtype: int64

# %% [markdown]
# Pergunta 3: Quantas pessoas foram vítimas de balas perdidas em 2024? E quantas vítimas teve o estado com mais casos?
#
# Ao total foram 13 vítimas de balas perdidas (8 vítimas fatais e 5 vítimas feridas.). O Estado do Rio de Janeiro teve o maior número de vítimas (5 vítimas), correspondendo a, aproximadamente, 38.46%.

# %%
df_bala_perdida= df[df['motivo_principal'] == 'Disparo Acidental']
df_bala_perdida
# Out:
#       id_ocorrencia              uf                   cidade  \
# 170           68780           Bahia         LAURO DE FREITAS
# 426           68500      Pernambuco                   OLINDA
# 625           68292      Pernambuco                   RECIFE
# 1370          67496  Rio de Janeiro                     MAGÉ
# 1981          66845  Rio de Janeiro                NILÓPOLIS
# 4539          64051           Bahia                 CAMACARI
# 4811          63761            Pará                    BELEM
# 5001          63563            Pará                    BELEM
# 5189          63359  Rio de Janeiro              SÃO GONÇALO
# 5770          62731  Rio de Janeiro           RIO DE JANEIRO
# 6125          62360           Bahia            MADRE DE DEUS
# 6395          62072  Rio de Janeiro                 MESQUITA
# 6742          61709      Pernambuco  JABOATAO DOS GUARARAPES
#
#                                                endereco            bairro  \
# ...

# %%
df_bala_perdida[["uf","agentes_feridos_ocorrencia", "civis_mortos_ocorrencia", "civis_feridos_ocorrencia","agentes_mortos_ocorrencia"]].value_counts("uf")
# Out:
# uf
# Rio de Janeiro    5
# Bahia             3
# Pernambuco        3
# Pará              2
# Name: count, dtype: int64

# %%
df_vitimas = pd.read_excel("C:/Users/Acer/Desktop/fogo_cruzado2/exercicio1_vitimas.xlsx")

# %%
df_vitimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5936 entries, 0 to 5935
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_ocorrencia           5936 non-null   int64
#  1   uf                      5936 non-null   object
#  2   endereco                5936 non-null   object
#  3   cidade                  5936 non-null   object
#  4   bairro                  5936 non-null   object
#  5   sub_bairro              450 non-null    object
#  6   localidade              2003 non-null   object
#  7   latitude                5936 non-null   float64
#  8   longitude               5936 non-null   float64
#  9   data_ocorrencia         5936 non-null   datetime64[ns]
#  10  hora_ocorrencia         5936 non-null   object
#  11  presenca_agentes        5936 non-null   object
#  12  acao_policial           5936 non-null   object
#  13  unidades_policiais      1990 non-null   object
# ...

# %%
df_idade = df_vitimas[df_vitimas["faixa_etaria"] == "Criança"]
df_idade
# Out:
#       id_ocorrencia              uf  \
# 195           68742           Bahia
# 196           68734  Rio de Janeiro
# 202           68729           Bahia
# 219           68708           Bahia
# 301           68611  Rio de Janeiro
# 320           68588           Bahia
# 321           68588           Bahia
# 322           68588           Bahia
# 331           68583  Rio de Janeiro
# 391           68509  Rio de Janeiro
# 393           68509  Rio de Janeiro
# 635           68270  Rio de Janeiro
# 672           68227  Rio de Janeiro
# 886           67976  Rio de Janeiro
# 889           67971            Pará
# 985           67861  Rio de Janeiro
# 1213          67592  Rio de Janeiro
# 1367          67410           Bahia
# 1678          67071  Rio de Janeiro
# 1813          66932  Rio de Janeiro
# 1889          66843  Rio de Janeiro
# 1940          66779           Bahia
# 2406          66243      Pernambuco
# 2765          65733  Rio de Janeiro
# 2979          65407  Rio de Janeiro
# ...

# %% [markdown]
# Respondendo a Pergunta 5.

# %%
df_local = df_idade[df_idade["local"] == "Residência" ] 
df_local_filtered = df_local[df_local["circunstancias_vitima"] == "Bala perdida"]
df_local_filtered
# Out:
#       id_ocorrencia              uf  \
# 219           68708           Bahia
# 3126          65227  Rio de Janeiro
# 5377          62372           Bahia
# 5869          61751  Rio de Janeiro
#
#                                                endereco              cidade  \
# 219                  R. Lindóia, Itinga - Salvador - BA            SALVADOR
# 3126  Morro da Mineira - Catumbi, Rio de Janeiro - R...      RIO DE JANEIRO
# 5377                          Mussurunga, Salvador - BA            SALVADOR
# 5869   Coelho da Rocha, São João de Meriti - RJ, Brasil  SÃO JOÃO DE MERITI
#
#                bairro sub_bairro                                 localidade  \
# 219            ITINGA        NaN                                        NaN
# 3126          CATUMBI        NaN  MORRO DA MINEIRA (COMPLEXO DO SAO CARLOS)
# 5377       MUSSURUNGA        NaN                                        NaN
# 5869  COELHO DA ROCHA        NaN                                        NaN
#
# ...

# %%
df_local_filtered["situacao"]
# Out:
# 219      Morta
# 3126    Ferida
# 5377    Ferida
# 5869    Ferida
# Name: situacao, dtype: object

# %%
df_local["circunstancias_vitima"]
# Out:
# 219          Bala perdida
# 3126         Bala perdida
# 5079    Sem identificação
# 5080    Sem identificação
# 5182    Sem identificação
# 5377         Bala perdida
# 5869         Bala perdida
# Name: circunstancias_vitima, dtype: object

# %%
df_qualificacao = df_vitimas[df_vitimas["qualificacoes_vitima"] == "funcionários de limpeza urbana" ]
df_qualificacao
# Out:
# Empty DataFrame
# Columns: [id_ocorrencia, uf, endereco, cidade, bairro, sub_bairro, localidade, latitude, longitude, data_ocorrencia, hora_ocorrencia, presenca_agentes, acao_policial, unidades_policiais, motivo_principal, motivos_complementares, outros_recortes, ocorrencia_relacionada, id_vitima, tipo, situacao, data_morte, idade, faixa_etaria, raca, genero, local, circunstancias_vitima, qualificacoes_vitima, status_servico, observacoes_gerais, status_politico, posicao_politico, partido_político, unidade_agente, posicao_agente, coorporacao_agente, status_agente, tipo_pessoa]
# Index: []
#
# [0 rows x 39 columns]

# %%
df_vitimas["qualificacoes_vitima"].value_counts()
# Out:
# qualificacoes_vitima
# Não identificado                             4706
# PPTE                                          498
# Outros                                        315
# Agente de segurança                           203
# Mototaxista                                    46
# Motorista de aplicativo                        43
# Entregador / Motoboy                           24
# Outros,PPTE                                    21
# Gestante                                       10
# Político                                        8
# Não identificado,Outros                         7
# Liderança religiosa                             5
# Entregador / Motoboy,Mototaxista                4
# Vendedor ambulante                              4
# Rifeiro                                         3
# Motorista de aplicativo,Outros                  3
# Gestante,Outros                                 3
# Não identificado,Político                       3
# ...

# %% [markdown]
# Respondendo a pergunta 6

# %%
df[df["id_ocorrencia"] == 67820]
# Out:
#       id_ocorrencia          uf  cidade  \
# 1069          67820  Pernambuco  OLINDA
#
#                                                endereco            bairro  \
# 1069  Via do Contôrno - Jardim Atlântico, Olinda - P...  JARDIM ATLANTICO
#
#      sub_bairro localidade  latitude  longitude data_ocorrencia  ...  \
# 1069        NaN        NaN -7.972683 -34.846196      2024-10-30  ...
#
#      civis_feridos_ocorrencia agentes_mortos_ocorrencia  \
# 1069                      NaN                       NaN
#
#      agentes_feridos_ocorrencia chacina_ocorrencia unidades_policiais  \
# 1069                        NaN                Não                NaN
#
#          motivo_principal  motivos_complementares  outros_recortes  \
# 1069  Homicidio/Tentativa                     NaN              NaN
#
#       transporte_interrompido ocorrencia_relacionada
# 1069                      Não                    NaN
#
# [1 rows x 26 columns]
